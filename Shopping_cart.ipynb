# %% [markdown]
# <a href="https://colab.research.google.com/github/tmolapo300/python-learning/blob/main/Shopping_cart.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Multi-item shopping cart

foods = []
prices = []

while True:
  food = input("Enter a food you want to purchase (q to quit): ")
  if food.lower() == "q":
      break
  else:
    price = float(input("Enter the price of the food: "))
    foods.append(food)
    prices.append(price)

print("\n--- YOUR CART ---")
total = 0

for i in range(len(foods)):
  print(f"{foods[i]}  R{prices[i]:.2f}")
  total += prices[i]

print(f"\nTotal Bill: R{total:.2f}")
