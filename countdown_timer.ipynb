# %% [markdown]
# <a href="https://colab.research.google.com/github/tmolapo300/python-learning/blob/main/countdown_timer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import time

my_time = int(input("Enter time in seconds: "))

for x in range(my_time, 0, -1):
  seconds = x % 60
  minutes = int(x / 60) % 60
  hours = int(x / 3600)
  print(f"{hours:02}:{minutes:02}:{seconds:02}")
  time.sleep(1)



print("TIME'S UP!")
# Out:
# Enter time in seconds: 9
# 00:00:09
# 00:00:08
# 00:00:07
# 00:00:06
# 00:00:05
# 00:00:04
# 00:00:03
# 00:00:02
# 00:00:01
# TIME'S UP!
