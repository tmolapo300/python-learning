# %% [markdown]
# <a href="https://colab.research.google.com/github/tmolapo300/python-learning/blob/main/ATM_Withdrawal_Simulator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
balance = 1000

withdrawal = float(input("How much would you like to withdraw? "))

if withdrawal <= 0:
  print("Invalid amount.")

elif withdrwal > balance:
  print("Insufficient funds!")
else:
  balance -= withdrawal
  print(f"Withdrawal successful! Remaining balance: R{balance:.2f} ")
# Out:
# How much would you like to withdraw? 500
# Withdrawal successful! Remaining balance: R500.00
