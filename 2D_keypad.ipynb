# %% [markdown]
# <a href="https://colab.research.google.com/github/tmolapo300/python-learning/blob/main/2D_keypad.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
num_pad = ((1, 2, 3,),
           (4, 5, 6),
           (7, 8, 9),
           ("*", 0, "#"))

for row in num_pad:
  for num in row:
    print(num, end=" ")
  print()
# Out:
# 1 2 3
# 4 5 6
# 7 8 9
# * 0 #
