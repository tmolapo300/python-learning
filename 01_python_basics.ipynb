# %% [markdown]
# <a href="https://colab.research.google.com/github/tmolapo300/python-learning/blob/main/01_python_basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello World")
# Out:
# Hello World

# %%
print("I like eating pizza")
# Out:
# I like eating pizza

# %%
# My first ever code so excited#

# %%
first_name = "Thato"

# %%
print(f"Hello {first_name}")
# Out:
# Hello Thato

# %%
food = "pizza"

# %%
print(f"You like {food}")
# Out:
# You like pizza

# %%
email = "tmolapo300@fake.com"

# %%
print(f"Your email is {email}")
# Out:
# Your email is tmolapo300@fake.com

# %%
# 5,7,10 are Strings#

# %%
#Integers nr 14,16,19 and remember no quotes#

# %%
age = 25

# %%
print(f"You are {age} years old")
# Out:
# You are 25 years old

# %%
quantity = 3

# %%
print(f"You are buying {quantity} items")
# Out:
# You are buying 3 items

# %%
num_of_students = 34

# %%
print(f"Your class has {num_of_students} students")
# Out:
# Your class has 34 students

# %%
#Float nr 24,33,35#

# %%
price = 11.23

# %%
print(f"The price is R{price}")
# Out:
# The price is R11.23

# %%
gpa = 4.2

# %%
print(f"Your gpa is {gpa}")
# Out:
# Your gpa is 4.2

# %%
distance = 4.3

# %%
print(f"You ran {distance} km")
# Out:
# You ran 4.3 km

# %%
#Boolean (True/False)#

# %%
is_student = True

# %%
if is_student:
    print("You are a student")
else:
  print("You are not a student")
# Out:
# You are a student

# %%
for_sale = True

# %%
if for_sale:
  print("That item is for sale")
else:
  print("That item is NOT for sale")
# Out:
# That item is for sale

# %%
is_online = True

# %%
if is_online:
  print("Thabo is online")
else:
  print("Thabo is offline")
# Out:
# Thabo is online

# %% [markdown]
# ### Typecasting (process pf converting a variable from one data type to another)
#   str(), int(), float(), bool()

# %%
name = "Sebastian Stellos "

# %%
age = 19

# %%
gpa = 4.2

# %%
is_student = True

# %%
gpa = int(gpa)
print((gpa))
# Out:
# 4

# %%
age = float(age)
print((age))
# Out:
# 19.0

# %%
age = str(age)
print(type(age))
# Out:
# <class 'str'>

# %%
name = bool(name)
print(name)
# Out:
# True

# %% [markdown]
# # input() A function that prompts the user to enter data returns that entered data aas a string

# %%
name = input("What is your name?: ")
# Out:
# What is your name?: Sebastian

# %%
print(f"Hello {name}! ")
# Out:
# Hello Sebastian!

# %%
age = int(input("What is your age?: "))
age = age + 1
print(f"Hello {name}!")
print("Happy Birthday!")
print(f"You are {age} years old")
# Out:
# What is your age?: 25
# Hello Sebastian!
# Happy Birthday!
# You are 26 years old

# %% [markdown]
# #Exercise 1 Rectangle Area Calc

# %%
length = float(input("Enter the lenght: "))
Width = float(input("Enter the width: "))
area = length * Width
print(f"The area is: {area}")
# Out:
# Enter the lenght: 6.2
# Enter the width: 4.5
# The area is: 27.900000000000002

# %% [markdown]
# #Exercise 2 Shopping Cart Program

# %%
item = input("What item would you like to purchase?: ")
price = float(input("What is the price?: "))
quantity = int(input("How many would you like?: "))
total = price * quantity

print(f"You have bought {quantity} x {item}/s")
print(f"Your total is: R{total}")
# Out:
# What item would you like to purchase?: Beef Burger
# What is the price?: 56.36
# How many would you like?: 4
# You have bought 4 x Beef Burger/s
# Your total is: R225.44

# %% [markdown]
# #Bonus exercise: A Madlibs game
# Word game where you create a story by filling in random words

# %%
adjective1 = input("Enter an adjective: ")
noun1 = input("Enter a noun: ")
adjective2 = input("Enter an adjective: ")
verb1 = input("Enter a verb: ")
adjective3 = input("Enter an adjective: ")

print(f"Today I went to a {adjective1} zoo.")
print(f"In an exhibit, I saw a {noun1}")
print(f"{noun1} is a {adjective2} feline and it was {verb1}")
print(f"I was {adjective3}!")
# Out:
# Enter an adjective: sketchy
# Enter a noun: tiger
# Enter an adjective: huge
# Enter a verb: eating
# Enter an adjective: ecstatic
# Today I went to a sketchy zoo.
# In an exhibit, I saw a tiger
# tiger is a huge feline and it was eating
# I was ecstatic!
